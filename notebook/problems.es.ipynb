# %% [markdown]
# # Problemas de prueba de hipótesis

# %% [markdown]
# ## Ejercicio 1
#
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?
#
# Para sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %% [markdown]
# #### Hipótesis nula (H₀): No existe una diferencia significativa en la pérdida de peso promedio entre las dos dietas.
# #### Hipótesis alternativa (H₁): Existe una diferencia significativa en la pérdida de peso promedio entre las dos dietas.

# %%
import scipy.stats as stats

# Datos de pérdida de peso
dieta_1 = [2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5]
dieta_2 = [3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2]

# Prueba t de Student
valor_t, valor_p = stats.ttest_ind(dieta_1, dieta_2)

print(f"Valor t: {valor_t}")
print(f"Valor p: {valor_p}")
# Out:
# Valor t: -3.5383407969933938
# Valor p: 0.004083270191713912

# %% [markdown]
# #### Conclusión
#
# Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta. La segunda dieta (Diet 2)resultó en una mayor pérdida de peso promedio en comparación con la primera dieta (Diet 1).

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## Ejercicio 2
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %% [markdown]
# - **Hipótesis nula (H₀)**: Las medias de rendimiento de maíz de los tres tipos de fertilizantes son iguales.
# - **Hipótesis alternativa (H₁)**: Al menos una de las medias de rendimiento de maíz de los tres tipos de fertilizantes es diferente.

# %%
import scipy.stats as stats

# Datos de rendimiento de maíz
fertilizante_1 = [20, 21, 20, 19, 20]
fertilizante_2 = [22, 21, 23, 22, 21]
fertilizante_3 = [24, 23, 22, 23, 24]

# Realizar la prueba ANOVA de una vía
f_stat, p_value = stats.f_oneway(fertilizante_1, fertilizante_2, fertilizante_3)

print(f"Valor F: {f_stat}")
print(f"Valor p: {p_value}")
# Out:
# Valor F: 20.315789473684188
# Valor p: 0.00014047824793190475

# %% [markdown]
# #### Conclusión
#
# Dado que el valor p es mucho menor que 0.05, podemos concluir que hay una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes.
# Por lo que los diferentes fertilizantes afectan de manera distinta el rendimiento del maíz.

# %%
# Que fertilizante es mejor 

import pandas as pd
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Crear un DataFrame con los datos
data = {
    'rendimiento': fertilizante_1 + fertilizante_2 + fertilizante_3,
    'fertilizante': ['Fertilizante 1']*5 + ['Fertilizante 2']*5 + ['Fertilizante 3']*5
}

df = pd.DataFrame(data)

# Realizar la prueba de Tukey
tukey_result = pairwise_tukeyhsd(endog=df['rendimiento'], groups=df['fertilizante'], alpha=0.05)
print(tukey_result)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#     group1         group2     meandiff p-adj  lower  upper  reject
# ------------------------------------------------------------------
# Fertilizante 1 Fertilizante 2      1.8 0.0099 0.4572 3.1428   True
# Fertilizante 1 Fertilizante 3      3.2 0.0001 1.8572 4.5428   True
# Fertilizante 2 Fertilizante 3      1.4 0.0409 0.0572 2.7428   True
# ------------------------------------------------------------------

# %% [markdown]
# Para determinar el mejor fertilizante, revisamos la columna “rechazar” en la tabla de resultados. Si el valor es “Verdadero”, hay una diferencia significativa entre los grupos comparados.
#
# Luego, miramos la columna “media”:
#
# Si es positiva, “grupo2” tiene un rendimiento mayor que “grupo1”.
# Si es negativa, “grupo1” tiene un rendimiento mayor que “grupo2”.
#
# En este caso, todos los fertilizantes difieren significativamente:
#
# El tercer fertilizante tiene el rendimiento promedio más alto.
# Le sigue el segundo fertilizante.
# El primero tiene el rendimiento más bajo.
#
# Por lo tanto, el tercer fertilizante es el mejor según estos resultados.
